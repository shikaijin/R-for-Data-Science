# %%
library(tidyverse)

# %%
library(nycflights13)

# %%
# Use ggplot to create a scatterplot of class vs drv
ggplot(mpg, aes(x = drv, y = class)) +
  geom_point()
# Out:
# plot without title

# %%
# What’s gone wrong with the following code? Why are the points not blue?
## The points are not blue since color = "blue" is inside aes(), which gives an 
## aesthetic mapping `color` -> "blue", and color becomes an additional discrete variable.
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %%
# Consider the flights dataset in the package nycflights13. Recreate the R code necessary to generate
# the following graph, which shows the average arrival delay and departure delay by origins.
origin_avg_delay <-
  flights %>% 
  group_by(origin) %>% 
  summarize(arrival = mean(arr_delay, na.rm = TRUE), departure = mean(flights$dep_delay, na.rm=TRUE)) %>%
  ungroup() %>% 
  gather(Type, avg_delay, arrival:departure)
  
ggplot(origin_avg_delay, aes(x = origin, y = avg_delay, fill = Type)) +
  geom_col(position = "dodge") +
  labs(
    y = "Average Delay", 
    title = "Average Arrival Delay and Departure Delay by Origins"
  )
# Out:
# plot without title

# %%
# consider the diamonds dataset in the package ggplot2. If you have loaded tidyverse, you will have
# this dataset.
# Compute the average price of the diamonds grouped by the quality of the cut. Do you think the
# results are reasonable?
(avg_price <- summarize(group_by(diamonds, cut), avg_price = mean(price, na.rm = TRUE))$avg_price)
# Out:
# [1] 4358.758 3928.864 3981.760 4584.258 3457.542

# %%
# Create histograms of the price of the diamonds by the variable cut.
ggplot(diamonds, aes(x = price)) +
  geom_histogram() +
  facet_grid(cut ~ ., scales = "free_y")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# Create a scatterplot of price vs carat using diamonds with cut equals "Ideal" and clarity equals
# "VS2". Map the colors of the points to the color variable in diamonds to reveal the diamond color.
diamonds_q5 <- filter(diamonds, cut == "Ideal", clarity == "VS2")
ggplot(diamonds_q5, aes(x = carat, y = price, color = color)) +
  geom_point(size = 0.9)
# Out:
# plot without title

# %%
# Recreate the R code
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
  geom_point() +
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# Recreate the R code. The smooth lines correspond to the data points with different values of drv.
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) +
  geom_smooth(mapping = aes(x = displ, y = hwy, group = drv), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# Recreate the R code. The smooth line corresponds to the data points with drv equals "r".
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_smooth(data = filter(mpg, drv == "r"), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# Recreate the R code
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) +
  geom_point() +
  geom_smooth(se = FALSE)

ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, color = drv)) +
  geom_smooth(mapping = aes(x = displ, y = hwy), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title
